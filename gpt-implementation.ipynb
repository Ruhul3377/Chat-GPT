# %% [markdown]
# <a href="https://www.kaggle.com/code/ruhul77/gpt-implementation?scriptVersionId=116829454" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")
model = GPT2LMHeadModel.from_pretrained("gpt2-large", pad_token_id=tokenizer.eos_token_id)
# Out:
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.02G [00:00<?, ?B/s]

# %%
input_sentence = "will Artificial Intelligence take the world?"

# %%
input_ids = tokenizer.encode(input_sentence, return_tensors="pt")
input_ids
# Out:
# tensor([[10594, 35941,  9345,  1011,   262,   995,    30]])

# %%
output =model.generate(
    input_ids,
    max_length=100,
    num_beams=5,
    no_repeat_ngram_size=2,
    early_stopping=True
)

# %%
tokenizer.decode(output[0], skip_special_tokens=True)
# Out:
# "will Artificial Intelligence take the world?\n\nI think it's going to happen, but I don't know if it will happen in the next 10 years. I think there's a lot of work to be done before we get to that point. But I do think that AI will be a big part of the future. It's just a question of how big."
